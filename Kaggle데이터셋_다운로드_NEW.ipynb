# %%
# !pip install kaggle==1.8
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 12.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    -------------------- ------------------- 5.2/10.1 MB 29.0 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.1 MB 23.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 21.6 MB/s  0:00:00
# ...
#
#    ----------- ----------------------------  4/14 [protobuf]
#    ----------- ----------------------------  4/14 [protobuf]
#    -------------- -------------------------  5/14 [pathspec]
#    ---------------------- -----------------  8/14 [click]
#    ---------------------------- ----------- 10/14 [mypy]
#    ---------------------------- ----------- 10/14 [mypy]
#    ---------------------------- ----------- 10/14 [mypy]
#    ---------------------------- ----------- 10/14 [mypy]
# ...

# %% [markdown]
# ## **Runtime** -> **Restart Session** 후 다음 내용 실행

# %%
import kaggle
print(kaggle.__version__)
# Out:
# 1.8.0

# %%
# python-dotenv를 설치하고
# !pip install python-dotenv

# %%
# load_dotenv()로.env

# %%
# Colab 시크릿에서 Kaggle 토큰 가져오기
from google.colab import userdata
import os
# 환경 변수  읽어오기
Kaggle_username = os.getenv('kaggle_username')
kaggle_key = os.getenv('kaggle_key')
# 확인 (보안을 위해 실제 출력 시 주의하세요)
print() 


# 방법 1: 환경변수로 설정 (Kaggle 1.8+ 단일 토큰 방식)
os.environ['KAGGLE_API_TOKEN'] = userdata.get('KAGGLE_KEY')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Colab 시크릿에서 Kaggle 토큰 가져오기
# ----> 2 from google.colab import userdata
#       3 import os
#       5 # 방법 1: 환경변수로 설정 (Kaggle 1.8+ 단일 토큰 방식)
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# !kaggle competitions download -c titanic
# Out:
# Could not find kaggle.json. Make sure it's located in C:\Users\alsld\.kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/

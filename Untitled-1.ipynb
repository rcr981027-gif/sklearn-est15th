# %%
# .env파일 만들기
# KAGGLE_API_TOKEN ="KGAT_e656685~~~"
# python-dotenv로 .env 키값을 불러오기
import os
from dotenv import load_dotenv

load_dotenv()

# 환경 변수 KAGGLE_API_TOKEN를 확인
print(os.getenv("KAGGLE_API_TOKEN"))
# Out:
# KGAT_b3642cfbe48b396fef70c97578d149db
